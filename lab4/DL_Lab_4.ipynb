# %% [markdown]
# ## Name: Paras Shah
# ## Roll number: 25/AFI/08

# %% [markdown]
# # 1. Importing libraries

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models

# %% [markdown]
# # 2. Using GPU

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # 3. Dataset extraction (cifar-10)

# %%
transform_cifar = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# %%
train_cifar = datasets.CIFAR10(
    root="./data",
    train=True,
    transform=transform_cifar,
    download=True
)

test_cifar = datasets.CIFAR10(
    root="./data",
    train=False,
    transform=transform_cifar,
    download=True
)

train_loader_cifar = DataLoader(train_cifar, batch_size=64, shuffle=True)
test_loader_cifar = DataLoader(test_cifar, batch_size=64, shuffle=False)
# Out:
# 100%|██████████| 170M/170M [00:04<00:00, 35.5MB/s]

# %% [markdown]
# # 4. CNN Architecture

# %%
class CNN(nn.Module):
    def __init__(self, activation_fn):
        super(CNN, self).__init__()

        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            activation_fn,
            nn.BatchNorm2d(32),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            activation_fn,
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 8 * 8, 256),
            activation_fn,
            nn.Dropout(0.5),
            nn.Linear(256, 10)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# # 5. Weight initialization techniques

# %%
def initialize_weights(model, init_type):
    for m in model.modules():
        if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
            if init_type == "xavier":
                nn.init.xavier_uniform_(m.weight)
            elif init_type == "kaiming":
                nn.init.kaiming_uniform_(m.weight, nonlinearity="relu")
            elif init_type == "random":
                nn.init.normal_(m.weight, mean=0, std=0.01)

# %% [markdown]
# # 6. Activation functions

# %%
activations = {
    "relu": nn.ReLU(),
    "tanh": nn.Tanh(),
    "leaky_relu": nn.LeakyReLU(0.01)
}

# %% [markdown]
# # 7. Optimizer techniques

# %%
def get_optimizer(optimizer_name, model):
    if optimizer_name == "sgd":
        return optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
    elif optimizer_name == "adam":
        return optim.Adam(model.parameters(), lr=0.001)
    elif optimizer_name == "rmsprop":
        return optim.RMSprop(model.parameters(), lr=0.001)

# %% [markdown]
# # 8. Training function

# %%
def train(model, train_loader, test_loader, optimizer, criterion, epochs=10):
    train_losses = []
    test_accuracies = []

    for epoch in range(epochs):
        model.train()
        running_loss = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        avg_loss = running_loss / len(train_loader)
        train_losses.append(avg_loss)

        acc = evaluate(model, test_loader)
        test_accuracies.append(acc)

        print(f"Epoch [{epoch+1}/{epochs}]  Loss: {avg_loss:.4f}  Accuracy: {acc:.2f}%")

    return train_losses, test_accuracies

# %% [markdown]
# # 9. Evaluation function

# %%
def evaluate(model, test_loader):
    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    return accuracy

# %% [markdown]
# # 9. Looping for every different variation

# %%
history = {}
models = {}

for act_name, act_fn in activations.items():
    for init in ["xavier", "kaiming", "random"]:
        for opt in ["sgd", "adam", "rmsprop"]:
            key = (act_name, init, opt)
            print(f"\nTraining Model: {key}")

            model = CNN(act_fn).to(device)
            initialize_weights(model, init)

            optimizer = get_optimizer(opt, model)
            criterion = nn.CrossEntropyLoss()

            losses, accuracies = train(
                model,
                train_loader_cifar,
                test_loader_cifar,
                optimizer,
                criterion,
                epochs=20
            )

            models[key] = model
            history[key] = {
                "loss": losses,
                "accuracy": accuracies
            }
# Out:
# Training Model: ('relu', 'xavier', 'sgd')
# Epoch [1/20]  Loss: 1.8347  Accuracy: 44.81%
# Epoch [2/20]  Loss: 1.5613  Accuracy: 51.55%
# Epoch [3/20]  Loss: 1.3631  Accuracy: 56.56%
# Epoch [4/20]  Loss: 1.2216  Accuracy: 61.72%
# Epoch [5/20]  Loss: 1.1513  Accuracy: 64.36%
# Epoch [6/20]  Loss: 1.0854  Accuracy: 66.21%
# Epoch [7/20]  Loss: 1.0495  Accuracy: 67.79%
# Epoch [8/20]  Loss: 1.0184  Accuracy: 68.02%
# Epoch [9/20]  Loss: 0.9899  Accuracy: 69.36%
# Epoch [10/20]  Loss: 0.9570  Accuracy: 70.39%
# Epoch [11/20]  Loss: 0.9375  Accuracy: 71.47%
# Epoch [12/20]  Loss: 0.9204  Accuracy: 70.88%
# Epoch [13/20]  Loss: 0.9016  Accuracy: 71.40%
# Epoch [14/20]  Loss: 0.8871  Accuracy: 72.14%
# Epoch [15/20]  Loss: 0.8675  Accuracy: 71.83%
# Epoch [16/20]  Loss: 0.8605  Accuracy: 71.65%
# Epoch [17/20]  Loss: 0.8471  Accuracy: 71.47%
# Epoch [18/20]  Loss: 0.8375  Accuracy: 72.17%
# Epoch [19/20]  Loss: 0.8242  Accuracy: 74.89%
# Epoch [20/20]  Loss: 0.8190  Accuracy: 74.65%
#
# Training Model: ('relu', 'xavier', 'adam')
# Epoch [1/20]  Loss: 1.7866  Accuracy: 48.20%
# Epoch [2/20]  Loss: 1.4685  Accuracy: 57.16%
# Epoch [3/20]  Loss: 1.3288  Accuracy: 59.33%
# Epoch [4/20]  Loss: 1.2481  Accuracy: 62.20%
# Epoch [5/20]  Loss: 1.1818  Accuracy: 63.78%
# Epoch [6/20]  Loss: 1.1319  Accuracy: 66.59%
# Epoch [7/20]  Loss: 1.0940  Accuracy: 67.88%
# Epoch [8/20]  Loss: 1.0587  Accuracy: 68.14%
# Epoch [9/20]  Loss: 1.0344  Accuracy: 67.97%
# Epoch [10/20]  Loss: 1.0090  Accuracy: 69.07%
# Epoch [11/20]  Loss: 0.9818  Accuracy: 70.15%
# Epoch [12/20]  Loss: 0.9570  Accuracy: 70.10%
# Epoch [13/20]  Loss: 0.9440  Accuracy: 70.91%
# Epoch [14/20]  Loss: 0.9281  Accuracy: 71.04%
# Epoch [15/20]  Loss: 0.9069  Accuracy: 72.01%
# Epoch [16/20]  Loss: 0.8841  Accuracy: 73.10%
# Epoch [17/20]  Loss: 0.8757  Accuracy: 72.79%
# Epoch [18/20]  Loss: 0.8637  Accuracy: 73.97%
# Epoch [19/20]  Loss: 0.8410  Accuracy: 71.64%
# Epoch [20/20]  Loss: 0.8354  Accuracy: 74.73%
#
# Training Model: ('relu', 'xavier', 'rmsprop')
# Epoch [1/20]  Loss: 1.9347  Accuracy: 43.68%
# Epoch [2/20]  Loss: 1.5142  Accuracy: 49.73%
# Epoch [3/20]  Loss: 1.3758  Accuracy: 51.59%
# Epoch [4/20]  Loss: 1.2813  Accuracy: 50.17%
# Epoch [5/20]  Loss: 1.2129  Accuracy: 60.39%
# Epoch [6/20]  Loss: 1.1666  Accuracy: 64.89%
# Epoch [7/20]  Loss: 1.1090  Accuracy: 65.07%
# Epoch [8/20]  Loss: 1.0771  Accuracy: 65.13%
# Epoch [9/20]  Loss: 1.0423  Accuracy: 65.13%
# Epoch [10/20]  Loss: 1.0135  Accuracy: 67.83%
# Epoch [11/20]  Loss: 0.9853  Accuracy: 68.67%
# Epoch [12/20]  Loss: 0.9638  Accuracy: 70.83%
# Epoch [13/20]  Loss: 0.9430  Accuracy: 68.81%
# Epoch [14/20]  Loss: 0.9200  Accuracy: 69.93%
# Epoch [15/20]  Loss: 0.8968  Accuracy: 72.21%
# Epoch [16/20]  Loss: 0.8878  Accuracy: 72.13%
# Epoch [17/20]  Loss: 0.8715  Accuracy: 71.77%
# Epoch [18/20]  Loss: 0.8504  Accuracy: 71.71%
# Epoch [19/20]  Loss: 0.8397  Accuracy: 72.27%
# Epoch [20/20]  Loss: 0.8266  Accuracy: 73.84%
#
# Training Model: ('relu', 'kaiming', 'sgd')
# Epoch [1/20]  Loss: 1.8149  Accuracy: 45.38%
# Epoch [2/20]  Loss: 1.5283  Accuracy: 54.35%
# Epoch [3/20]  Loss: 1.3418  Accuracy: 57.41%
# Epoch [4/20]  Loss: 1.2167  Accuracy: 63.23%
# Epoch [5/20]  Loss: 1.1413  Accuracy: 63.20%
# Epoch [6/20]  Loss: 1.0938  Accuracy: 64.52%
# Epoch [7/20]  Loss: 1.0495  Accuracy: 66.28%
# Epoch [8/20]  Loss: 1.0178  Accuracy: 68.77%
# Epoch [9/20]  Loss: 0.9900  Accuracy: 69.00%
# Epoch [10/20]  Loss: 0.9626  Accuracy: 70.84%
# Epoch [11/20]  Loss: 0.9392  Accuracy: 70.98%
# Epoch [12/20]  Loss: 0.9238  Accuracy: 70.37%
# Epoch [13/20]  Loss: 0.9102  Accuracy: 70.80%
# Epoch [14/20]  Loss: 0.8903  Accuracy: 71.92%
# Epoch [15/20]  Loss: 0.8756  Accuracy: 72.38%
# Epoch [16/20]  Loss: 0.8602  Accuracy: 72.41%
# Epoch [17/20]  Loss: 0.8453  Accuracy: 72.94%
# Epoch [18/20]  Loss: 0.8428  Accuracy: 73.65%
# Epoch [19/20]  Loss: 0.8288  Accuracy: 74.77%
# Epoch [20/20]  Loss: 0.8238  Accuracy: 74.47%
#
# Training Model: ('relu', 'kaiming', 'adam')
# Epoch [1/20]  Loss: 1.8338  Accuracy: 49.27%
# Epoch [2/20]  Loss: 1.4968  Accuracy: 55.16%
# Epoch [3/20]  Loss: 1.3624  Accuracy: 60.31%
# Epoch [4/20]  Loss: 1.2722  Accuracy: 62.23%
# Epoch [5/20]  Loss: 1.2108  Accuracy: 63.02%
# Epoch [6/20]  Loss: 1.1508  Accuracy: 65.73%
# Epoch [7/20]  Loss: 1.1125  Accuracy: 66.62%
# Epoch [8/20]  Loss: 1.0730  Accuracy: 68.30%
# Epoch [9/20]  Loss: 1.0333  Accuracy: 68.60%
# Epoch [10/20]  Loss: 1.0126  Accuracy: 68.52%
# Epoch [11/20]  Loss: 0.9934  Accuracy: 70.18%
# Epoch [12/20]  Loss: 0.9644  Accuracy: 70.84%
# Epoch [13/20]  Loss: 0.9419  Accuracy: 70.48%
# Epoch [14/20]  Loss: 0.9286  Accuracy: 72.20%
# Epoch [15/20]  Loss: 0.9152  Accuracy: 71.63%
# Epoch [16/20]  Loss: 0.8964  Accuracy: 72.15%
# Epoch [17/20]  Loss: 0.8810  Accuracy: 72.80%
# Epoch [18/20]  Loss: 0.8668  Accuracy: 73.34%
# Epoch [19/20]  Loss: 0.8621  Accuracy: 73.50%
# Epoch [20/20]  Loss: 0.8393  Accuracy: 74.11%
#
# Training Model: ('relu', 'kaiming', 'rmsprop')
# Epoch [1/20]  Loss: 1.9660  Accuracy: 44.10%
# Epoch [2/20]  Loss: 1.5535  Accuracy: 46.85%
# Epoch [3/20]  Loss: 1.4155  Accuracy: 55.20%
# Epoch [4/20]  Loss: 1.3251  Accuracy: 58.02%
# Epoch [5/20]  Loss: 1.2564  Accuracy: 60.26%
# Epoch [6/20]  Loss: 1.2067  Accuracy: 61.45%
# Epoch [7/20]  Loss: 1.1567  Accuracy: 65.60%
# Epoch [8/20]  Loss: 1.1160  Accuracy: 66.57%
# Epoch [9/20]  Loss: 1.0822  Accuracy: 66.85%
# Epoch [10/20]  Loss: 1.0482  Accuracy: 66.05%
# Epoch [11/20]  Loss: 1.0316  Accuracy: 66.11%
# Epoch [12/20]  Loss: 0.9975  Accuracy: 69.14%
# Epoch [13/20]  Loss: 0.9783  Accuracy: 70.10%
# Epoch [14/20]  Loss: 0.9499  Accuracy: 68.25%
# Epoch [15/20]  Loss: 0.9247  Accuracy: 70.55%
# Epoch [16/20]  Loss: 0.9045  Accuracy: 72.01%
# Epoch [17/20]  Loss: 0.8938  Accuracy: 71.68%
# Epoch [18/20]  Loss: 0.8687  Accuracy: 73.37%
# Epoch [19/20]  Loss: 0.8540  Accuracy: 73.89%
# Epoch [20/20]  Loss: 0.8423  Accuracy: 70.88%
#
# Training Model: ('relu', 'random', 'sgd')
# Epoch [1/20]  Loss: 1.6826  Accuracy: 51.17%
# Epoch [2/20]  Loss: 1.3939  Accuracy: 56.92%
# Epoch [3/20]  Loss: 1.2129  Accuracy: 62.00%
# Epoch [4/20]  Loss: 1.1016  Accuracy: 64.85%
# Epoch [5/20]  Loss: 1.0306  Accuracy: 66.87%
# Epoch [6/20]  Loss: 0.9786  Accuracy: 68.78%
# Epoch [7/20]  Loss: 0.9502  Accuracy: 70.52%
# Epoch [8/20]  Loss: 0.9169  Accuracy: 70.45%
# Epoch [9/20]  Loss: 0.9024  Accuracy: 71.54%
# Epoch [10/20]  Loss: 0.8811  Accuracy: 71.20%
# Epoch [11/20]  Loss: 0.8630  Accuracy: 72.18%
# Epoch [12/20]  Loss: 0.8496  Accuracy: 73.76%
# Epoch [13/20]  Loss: 0.8405  Accuracy: 73.20%
# Epoch [14/20]  Loss: 0.8246  Accuracy: 74.13%
# Epoch [15/20]  Loss: 0.8240  Accuracy: 74.40%
# Epoch [16/20]  Loss: 0.8038  Accuracy: 75.28%
# Epoch [17/20]  Loss: 0.7966  Accuracy: 75.31%
# Epoch [18/20]  Loss: 0.7916  Accuracy: 75.14%
# Epoch [19/20]  Loss: 0.7840  Accuracy: 75.90%
# Epoch [20/20]  Loss: 0.7792  Accuracy: 75.78%
#
# Training Model: ('relu', 'random', 'adam')
# Epoch [1/20]  Loss: 1.5663  Accuracy: 54.12%
# Epoch [2/20]  Loss: 1.2841  Accuracy: 60.73%
# Epoch [3/20]  Loss: 1.1684  Accuracy: 62.48%
# Epoch [4/20]  Loss: 1.0890  Accuracy: 66.16%
# Epoch [5/20]  Loss: 1.0446  Accuracy: 64.35%
# Epoch [6/20]  Loss: 1.0062  Accuracy: 68.58%
# Epoch [7/20]  Loss: 0.9699  Accuracy: 68.48%
# Epoch [8/20]  Loss: 0.9454  Accuracy: 71.23%
# Epoch [9/20]  Loss: 0.9248  Accuracy: 72.00%
# Epoch [10/20]  Loss: 0.8928  Accuracy: 72.52%
# Epoch [11/20]  Loss: 0.8738  Accuracy: 73.16%
# Epoch [12/20]  Loss: 0.8558  Accuracy: 73.19%
# Epoch [13/20]  Loss: 0.8428  Accuracy: 74.05%
# Epoch [14/20]  Loss: 0.8183  Accuracy: 74.08%
# Epoch [15/20]  Loss: 0.8142  Accuracy: 74.63%
# Epoch [16/20]  Loss: 0.7965  Accuracy: 74.85%
# Epoch [17/20]  Loss: 0.7831  Accuracy: 74.88%
# Epoch [18/20]  Loss: 0.7722  Accuracy: 75.69%
# Epoch [19/20]  Loss: 0.7684  Accuracy: 76.14%
# Epoch [20/20]  Loss: 0.7546  Accuracy: 76.01%
#
# Training Model: ('relu', 'random', 'rmsprop')
# Epoch [1/20]  Loss: 1.6684  Accuracy: 49.03%
# Epoch [2/20]  Loss: 1.3539  Accuracy: 53.23%
# Epoch [3/20]  Loss: 1.2342  Accuracy: 59.82%
# Epoch [4/20]  Loss: 1.1612  Accuracy: 53.30%
# Epoch [5/20]  Loss: 1.1154  Accuracy: 58.28%
# Epoch [6/20]  Loss: 1.0689  Accuracy: 65.10%
# Epoch [7/20]  Loss: 1.0318  Accuracy: 68.61%
# Epoch [8/20]  Loss: 1.0019  Accuracy: 68.31%
# Epoch [9/20]  Loss: 0.9800  Accuracy: 68.27%
# Epoch [10/20]  Loss: 0.9491  Accuracy: 70.00%
# Epoch [11/20]  Loss: 0.9255  Accuracy: 67.56%
# Epoch [12/20]  Loss: 0.9018  Accuracy: 71.25%
# Epoch [13/20]  Loss: 0.8873  Accuracy: 70.82%
# Epoch [14/20]  Loss: 0.8668  Accuracy: 71.73%
# Epoch [15/20]  Loss: 0.8531  Accuracy: 71.41%
# Epoch [16/20]  Loss: 0.8361  Accuracy: 74.08%
# Epoch [17/20]  Loss: 0.8212  Accuracy: 73.12%
# Epoch [18/20]  Loss: 0.8110  Accuracy: 72.20%
# Epoch [19/20]  Loss: 0.7920  Accuracy: 70.53%
# Epoch [20/20]  Loss: 0.7813  Accuracy: 73.40%
#
# Training Model: ('tanh', 'xavier', 'sgd')
# Epoch [1/20]  Loss: 1.8128  Accuracy: 46.23%
# Epoch [2/20]  Loss: 1.4979  Accuracy: 51.22%
# Epoch [3/20]  Loss: 1.3637  Accuracy: 55.60%
# Epoch [4/20]  Loss: 1.2640  Accuracy: 58.66%
# Epoch [5/20]  Loss: 1.1914  Accuracy: 61.31%
# Epoch [6/20]  Loss: 1.1484  Accuracy: 63.33%
# Epoch [7/20]  Loss: 1.1085  Accuracy: 62.55%
# Epoch [8/20]  Loss: 1.0740  Accuracy: 64.49%
# Epoch [9/20]  Loss: 1.0510  Accuracy: 66.55%
# Epoch [10/20]  Loss: 1.0257  Accuracy: 67.54%
# Epoch [11/20]  Loss: 1.0079  Accuracy: 67.00%
# Epoch [12/20]  Loss: 0.9844  Accuracy: 67.23%
# Epoch [13/20]  Loss: 0.9762  Accuracy: 67.99%
# Epoch [14/20]  Loss: 0.9647  Accuracy: 67.56%
# Epoch [15/20]  Loss: 0.9602  Accuracy: 68.81%
# Epoch [16/20]  Loss: 0.9432  Accuracy: 69.20%
# Epoch [17/20]  Loss: 0.9361  Accuracy: 69.37%
# Epoch [18/20]  Loss: 0.9277  Accuracy: 69.50%
# Epoch [19/20]  Loss: 0.9236  Accuracy: 68.79%
# Epoch [20/20]  Loss: 0.9087  Accuracy: 70.14%
#
# Training Model: ('tanh', 'xavier', 'adam')
# Epoch [1/20]  Loss: 1.9525  Accuracy: 47.55%
# Epoch [2/20]  Loss: 1.4796  Accuracy: 52.89%
# Epoch [3/20]  Loss: 1.3380  Accuracy: 54.74%
# Epoch [4/20]  Loss: 1.2566  Accuracy: 59.76%
# Epoch [5/20]  Loss: 1.2007  Accuracy: 61.18%
# Epoch [6/20]  Loss: 1.1634  Accuracy: 62.10%
# Epoch [7/20]  Loss: 1.1408  Accuracy: 63.56%
# Epoch [8/20]  Loss: 1.1207  Accuracy: 62.88%
# Epoch [9/20]  Loss: 1.1003  Accuracy: 63.11%
# Epoch [10/20]  Loss: 1.0833  Accuracy: 65.23%
# Epoch [11/20]  Loss: 1.0661  Accuracy: 64.27%
# Epoch [12/20]  Loss: 1.0558  Accuracy: 66.07%
# Epoch [13/20]  Loss: 1.0497  Accuracy: 65.32%
# Epoch [14/20]  Loss: 1.0373  Accuracy: 65.49%
# Epoch [15/20]  Loss: 1.0326  Accuracy: 66.61%
# Epoch [16/20]  Loss: 1.0229  Accuracy: 65.92%
# Epoch [17/20]  Loss: 1.0065  Accuracy: 66.47%
# Epoch [18/20]  Loss: 1.0093  Accuracy: 66.92%
# Epoch [19/20]  Loss: 1.0007  Accuracy: 65.91%
# Epoch [20/20]  Loss: 0.9903  Accuracy: 66.70%
#
# Training Model: ('tanh', 'xavier', 'rmsprop')
# Epoch [1/20]  Loss: 1.9944  Accuracy: 34.28%
# Epoch [2/20]  Loss: 1.5598  Accuracy: 47.03%
# Epoch [3/20]  Loss: 1.4375  Accuracy: 49.56%
# Epoch [4/20]  Loss: 1.3445  Accuracy: 53.93%
# Epoch [5/20]  Loss: 1.2836  Accuracy: 55.85%
# Epoch [6/20]  Loss: 1.2345  Accuracy: 56.80%
# Epoch [7/20]  Loss: 1.1998  Accuracy: 59.20%
# Epoch [8/20]  Loss: 1.1710  Accuracy: 60.10%
# Epoch [9/20]  Loss: 1.1517  Accuracy: 59.74%
# Epoch [10/20]  Loss: 1.1337  Accuracy: 57.58%
# Epoch [11/20]  Loss: 1.1152  Accuracy: 60.05%
# Epoch [12/20]  Loss: 1.1001  Accuracy: 57.24%
# Epoch [13/20]  Loss: 1.0921  Accuracy: 61.51%
# Epoch [14/20]  Loss: 1.0790  Accuracy: 63.25%
# Epoch [15/20]  Loss: 1.0626  Accuracy: 62.86%
# Epoch [16/20]  Loss: 1.0562  Accuracy: 65.15%
# Epoch [17/20]  Loss: 1.0437  Accuracy: 54.71%
# Epoch [18/20]  Loss: 1.0396  Accuracy: 62.77%
# Epoch [19/20]  Loss: 1.0337  Accuracy: 65.11%
# Epoch [20/20]  Loss: 1.0225  Accuracy: 61.32%
#
# Training Model: ('tanh', 'kaiming', 'sgd')
# Epoch [1/20]  Loss: 1.7973  Accuracy: 48.42%
# Epoch [2/20]  Loss: 1.4583  Accuracy: 54.80%
# Epoch [3/20]  Loss: 1.3307  Accuracy: 54.43%
# Epoch [4/20]  Loss: 1.2467  Accuracy: 57.65%
# Epoch [5/20]  Loss: 1.1889  Accuracy: 61.82%
# Epoch [6/20]  Loss: 1.1331  Accuracy: 61.44%
# Epoch [7/20]  Loss: 1.1011  Accuracy: 64.15%
# Epoch [8/20]  Loss: 1.0631  Accuracy: 63.71%
# Epoch [9/20]  Loss: 1.0384  Accuracy: 64.57%
# Epoch [10/20]  Loss: 1.0200  Accuracy: 66.45%
# Epoch [11/20]  Loss: 1.0006  Accuracy: 66.49%
# Epoch [12/20]  Loss: 0.9873  Accuracy: 64.08%
# Epoch [13/20]  Loss: 0.9754  Accuracy: 67.74%
# Epoch [14/20]  Loss: 0.9649  Accuracy: 67.97%
# Epoch [15/20]  Loss: 0.9566  Accuracy: 68.93%
# Epoch [16/20]  Loss: 0.9381  Accuracy: 69.38%
# Epoch [17/20]  Loss: 0.9330  Accuracy: 68.76%
# Epoch [18/20]  Loss: 0.9264  Accuracy: 69.42%
# Epoch [19/20]  Loss: 0.9172  Accuracy: 68.96%
# Epoch [20/20]  Loss: 0.9159  Accuracy: 69.98%
#
# Training Model: ('tanh', 'kaiming', 'adam')
# Epoch [1/20]  Loss: 1.9890  Accuracy: 48.18%
# Epoch [2/20]  Loss: 1.4714  Accuracy: 53.28%
# Epoch [3/20]  Loss: 1.3333  Accuracy: 57.20%
# Epoch [4/20]  Loss: 1.2553  Accuracy: 58.64%
# Epoch [5/20]  Loss: 1.2043  Accuracy: 60.60%
# Epoch [6/20]  Loss: 1.1731  Accuracy: 61.81%
# Epoch [7/20]  Loss: 1.1491  Accuracy: 62.78%
# Epoch [8/20]  Loss: 1.1301  Accuracy: 62.64%
# Epoch [9/20]  Loss: 1.1052  Accuracy: 62.97%
# Epoch [10/20]  Loss: 1.0925  Accuracy: 63.99%
# Epoch [11/20]  Loss: 1.0808  Accuracy: 64.92%
# Epoch [12/20]  Loss: 1.0685  Accuracy: 63.51%
# Epoch [13/20]  Loss: 1.0534  Accuracy: 64.45%
# Epoch [14/20]  Loss: 1.0378  Accuracy: 65.37%
# Epoch [15/20]  Loss: 1.0371  Accuracy: 64.56%
# Epoch [16/20]  Loss: 1.0255  Accuracy: 66.58%
# Epoch [17/20]  Loss: 1.0158  Accuracy: 66.17%
# Epoch [18/20]  Loss: 1.0147  Accuracy: 66.61%
# Epoch [19/20]  Loss: 1.0027  Accuracy: 67.28%
# Epoch [20/20]  Loss: 0.9986  Accuracy: 66.09%
#
# Training Model: ('tanh', 'kaiming', 'rmsprop')
# Epoch [1/20]  Loss: 1.9734  Accuracy: 47.02%
# Epoch [2/20]  Loss: 1.4962  Accuracy: 51.40%
# Epoch [3/20]  Loss: 1.3669  Accuracy: 54.00%
# Epoch [4/20]  Loss: 1.2834  Accuracy: 57.35%
# Epoch [5/20]  Loss: 1.2233  Accuracy: 58.49%
# Epoch [6/20]  Loss: 1.1842  Accuracy: 61.12%
# Epoch [7/20]  Loss: 1.1586  Accuracy: 60.24%
# Epoch [8/20]  Loss: 1.1408  Accuracy: 55.21%
# Epoch [9/20]  Loss: 1.1187  Accuracy: 59.34%
# Epoch [10/20]  Loss: 1.1012  Accuracy: 60.02%
# Epoch [11/20]  Loss: 1.0905  Accuracy: 61.65%
# Epoch [12/20]  Loss: 1.0790  Accuracy: 64.11%
# Epoch [13/20]  Loss: 1.0623  Accuracy: 62.52%
# Epoch [14/20]  Loss: 1.0532  Accuracy: 65.93%
# Epoch [15/20]  Loss: 1.0496  Accuracy: 64.37%
# Epoch [16/20]  Loss: 1.0406  Accuracy: 65.04%
# Epoch [17/20]  Loss: 1.0309  Accuracy: 64.02%
# Epoch [18/20]  Loss: 1.0250  Accuracy: 65.94%
# Epoch [19/20]  Loss: 1.0153  Accuracy: 63.32%
# Epoch [20/20]  Loss: 1.0081  Accuracy: 64.24%
#
# Training Model: ('tanh', 'random', 'sgd')
# Epoch [1/20]  Loss: 1.7220  Accuracy: 45.98%
# Epoch [2/20]  Loss: 1.4651  Accuracy: 56.16%
# Epoch [3/20]  Loss: 1.3103  Accuracy: 57.89%
# Epoch [4/20]  Loss: 1.2243  Accuracy: 60.30%
# Epoch [5/20]  Loss: 1.1685  Accuracy: 61.30%
# Epoch [6/20]  Loss: 1.1243  Accuracy: 64.01%
# Epoch [7/20]  Loss: 1.0902  Accuracy: 64.90%
# Epoch [8/20]  Loss: 1.0543  Accuracy: 66.54%
# Epoch [9/20]  Loss: 1.0274  Accuracy: 67.03%
# Epoch [10/20]  Loss: 1.0071  Accuracy: 67.95%
# Epoch [11/20]  Loss: 0.9822  Accuracy: 68.14%
# Epoch [12/20]  Loss: 0.9745  Accuracy: 68.58%
# Epoch [13/20]  Loss: 0.9632  Accuracy: 69.55%
# Epoch [14/20]  Loss: 0.9385  Accuracy: 69.14%
# Epoch [15/20]  Loss: 0.9312  Accuracy: 68.34%
# Epoch [16/20]  Loss: 0.9256  Accuracy: 69.55%
# Epoch [17/20]  Loss: 0.9139  Accuracy: 68.02%
# Epoch [18/20]  Loss: 0.9055  Accuracy: 70.61%
# Epoch [19/20]  Loss: 0.8955  Accuracy: 69.35%
# Epoch [20/20]  Loss: 0.8916  Accuracy: 71.64%
#
# Training Model: ('tanh', 'random', 'adam')
# Epoch [1/20]  Loss: 1.6878  Accuracy: 46.78%
# Epoch [2/20]  Loss: 1.5013  Accuracy: 51.23%
# Epoch [3/20]  Loss: 1.3938  Accuracy: 48.00%
# Epoch [4/20]  Loss: 1.3071  Accuracy: 56.77%
# Epoch [5/20]  Loss: 1.2434  Accuracy: 58.55%
# Epoch [6/20]  Loss: 1.2001  Accuracy: 60.82%
# Epoch [7/20]  Loss: 1.1771  Accuracy: 61.29%
# Epoch [8/20]  Loss: 1.1565  Accuracy: 62.17%
# Epoch [9/20]  Loss: 1.1311  Accuracy: 61.76%
# Epoch [10/20]  Loss: 1.1182  Accuracy: 62.08%
# Epoch [11/20]  Loss: 1.1105  Accuracy: 63.97%
# Epoch [12/20]  Loss: 1.0963  Accuracy: 64.10%
# Epoch [13/20]  Loss: 1.0845  Accuracy: 63.14%
# Epoch [14/20]  Loss: 1.0731  Accuracy: 64.46%
# Epoch [15/20]  Loss: 1.0653  Accuracy: 64.09%
# Epoch [16/20]  Loss: 1.0491  Accuracy: 65.19%
# Epoch [17/20]  Loss: 1.0450  Accuracy: 65.50%
# Epoch [18/20]  Loss: 1.0359  Accuracy: 65.95%
# Epoch [19/20]  Loss: 1.0287  Accuracy: 66.13%
# Epoch [20/20]  Loss: 1.0205  Accuracy: 67.30%
#
# Training Model: ('tanh', 'random', 'rmsprop')
# Epoch [1/20]  Loss: 1.7470  Accuracy: 41.57%
# Epoch [2/20]  Loss: 1.5329  Accuracy: 46.09%
# Epoch [3/20]  Loss: 1.4422  Accuracy: 51.34%
# Epoch [4/20]  Loss: 1.3707  Accuracy: 54.23%
# Epoch [5/20]  Loss: 1.3120  Accuracy: 56.01%
# Epoch [6/20]  Loss: 1.2675  Accuracy: 54.48%
# Epoch [7/20]  Loss: 1.2316  Accuracy: 56.95%
# Epoch [8/20]  Loss: 1.1961  Accuracy: 54.77%
# Epoch [9/20]  Loss: 1.1760  Accuracy: 59.86%
# Epoch [10/20]  Loss: 1.1525  Accuracy: 60.99%
# Epoch [11/20]  Loss: 1.1296  Accuracy: 56.30%
# Epoch [12/20]  Loss: 1.1154  Accuracy: 62.66%
# Epoch [13/20]  Loss: 1.1021  Accuracy: 59.49%
# Epoch [14/20]  Loss: 1.0922  Accuracy: 62.58%
# Epoch [15/20]  Loss: 1.0770  Accuracy: 62.87%
# Epoch [16/20]  Loss: 1.0645  Accuracy: 60.24%
# Epoch [17/20]  Loss: 1.0547  Accuracy: 64.85%
# Epoch [18/20]  Loss: 1.0485  Accuracy: 61.10%
# Epoch [19/20]  Loss: 1.0426  Accuracy: 65.62%
# Epoch [20/20]  Loss: 1.0373  Accuracy: 65.19%
#
# Training Model: ('leaky_relu', 'xavier', 'sgd')
# Epoch [1/20]  Loss: 1.8212  Accuracy: 45.14%
# Epoch [2/20]  Loss: 1.5360  Accuracy: 50.23%
# Epoch [3/20]  Loss: 1.3793  Accuracy: 57.57%
# Epoch [4/20]  Loss: 1.2580  Accuracy: 59.88%
# Epoch [5/20]  Loss: 1.1616  Accuracy: 64.94%
# Epoch [6/20]  Loss: 1.0891  Accuracy: 66.13%
# Epoch [7/20]  Loss: 1.0477  Accuracy: 67.10%
# Epoch [8/20]  Loss: 1.0201  Accuracy: 68.19%
# Epoch [9/20]  Loss: 0.9857  Accuracy: 68.44%
# Epoch [10/20]  Loss: 0.9594  Accuracy: 69.34%
# Epoch [11/20]  Loss: 0.9398  Accuracy: 71.15%
# Epoch [12/20]  Loss: 0.9294  Accuracy: 72.18%
# Epoch [13/20]  Loss: 0.9072  Accuracy: 72.29%
# Epoch [14/20]  Loss: 0.8877  Accuracy: 71.15%
# Epoch [15/20]  Loss: 0.8837  Accuracy: 72.15%
# Epoch [16/20]  Loss: 0.8706  Accuracy: 71.88%
# Epoch [17/20]  Loss: 0.8602  Accuracy: 71.58%
# Epoch [18/20]  Loss: 0.8420  Accuracy: 72.88%
# Epoch [19/20]  Loss: 0.8347  Accuracy: 72.48%
# Epoch [20/20]  Loss: 0.8297  Accuracy: 73.17%
#
# Training Model: ('leaky_relu', 'xavier', 'adam')
# Epoch [1/20]  Loss: 1.7626  Accuracy: 50.57%
# Epoch [2/20]  Loss: 1.4267  Accuracy: 56.64%
# Epoch [3/20]  Loss: 1.2877  Accuracy: 61.59%
# Epoch [4/20]  Loss: 1.2041  Accuracy: 63.80%
# Epoch [5/20]  Loss: 1.1340  Accuracy: 65.56%
# Epoch [6/20]  Loss: 1.0891  Accuracy: 64.81%
# Epoch [7/20]  Loss: 1.0488  Accuracy: 67.34%
# Epoch [8/20]  Loss: 1.0179  Accuracy: 68.75%
# Epoch [9/20]  Loss: 0.9800  Accuracy: 70.39%
# Epoch [10/20]  Loss: 0.9563  Accuracy: 70.28%
# Epoch [11/20]  Loss: 0.9259  Accuracy: 70.55%
# Epoch [12/20]  Loss: 0.9065  Accuracy: 71.18%
# Epoch [13/20]  Loss: 0.8881  Accuracy: 73.02%
# Epoch [14/20]  Loss: 0.8666  Accuracy: 71.83%
# Epoch [15/20]  Loss: 0.8522  Accuracy: 73.79%
# Epoch [16/20]  Loss: 0.8419  Accuracy: 73.61%
# Epoch [17/20]  Loss: 0.8234  Accuracy: 73.51%
# Epoch [18/20]  Loss: 0.8009  Accuracy: 73.90%
# Epoch [19/20]  Loss: 0.7981  Accuracy: 75.12%
# Epoch [20/20]  Loss: 0.7841  Accuracy: 75.95%
#
# Training Model: ('leaky_relu', 'xavier', 'rmsprop')
# Epoch [1/20]  Loss: 1.9124  Accuracy: 48.63%
# Epoch [2/20]  Loss: 1.4804  Accuracy: 52.63%
# Epoch [3/20]  Loss: 1.3301  Accuracy: 54.65%
# Epoch [4/20]  Loss: 1.2398  Accuracy: 62.04%
# Epoch [5/20]  Loss: 1.1740  Accuracy: 61.93%
# Epoch [6/20]  Loss: 1.1214  Accuracy: 64.27%
# Epoch [7/20]  Loss: 1.0797  Accuracy: 59.57%
# Epoch [8/20]  Loss: 1.0457  Accuracy: 65.94%
# Epoch [9/20]  Loss: 1.0122  Accuracy: 66.99%
# Epoch [10/20]  Loss: 0.9896  Accuracy: 66.19%
# Epoch [11/20]  Loss: 0.9700  Accuracy: 58.69%
# Epoch [12/20]  Loss: 0.9372  Accuracy: 70.57%
# Epoch [13/20]  Loss: 0.9236  Accuracy: 68.31%
# Epoch [14/20]  Loss: 0.9055  Accuracy: 71.23%
# Epoch [15/20]  Loss: 0.8921  Accuracy: 62.47%
# Epoch [16/20]  Loss: 0.8713  Accuracy: 70.98%
# Epoch [17/20]  Loss: 0.8615  Accuracy: 72.93%
# Epoch [18/20]  Loss: 0.8555  Accuracy: 71.90%
# Epoch [19/20]  Loss: 0.8425  Accuracy: 67.64%
# Epoch [20/20]  Loss: 0.8229  Accuracy: 71.53%
#
# Training Model: ('leaky_relu', 'kaiming', 'sgd')
# Epoch [1/20]  Loss: 1.8068  Accuracy: 47.56%
# Epoch [2/20]  Loss: 1.5022  Accuracy: 54.46%
# Epoch [3/20]  Loss: 1.3227  Accuracy: 58.76%
# Epoch [4/20]  Loss: 1.2000  Accuracy: 63.22%
# Epoch [5/20]  Loss: 1.1188  Accuracy: 63.83%
# Epoch [6/20]  Loss: 1.0748  Accuracy: 65.92%
# Epoch [7/20]  Loss: 1.0411  Accuracy: 67.30%
# Epoch [8/20]  Loss: 1.0101  Accuracy: 68.43%
# Epoch [9/20]  Loss: 0.9850  Accuracy: 70.06%
# Epoch [10/20]  Loss: 0.9677  Accuracy: 70.10%
# Epoch [11/20]  Loss: 0.9471  Accuracy: 70.98%
# Epoch [12/20]  Loss: 0.9230  Accuracy: 71.02%
# Epoch [13/20]  Loss: 0.9124  Accuracy: 71.18%
# Epoch [14/20]  Loss: 0.9036  Accuracy: 71.50%
# Epoch [15/20]  Loss: 0.8875  Accuracy: 72.31%
# Epoch [16/20]  Loss: 0.8766  Accuracy: 72.31%
# Epoch [17/20]  Loss: 0.8583  Accuracy: 72.74%
# Epoch [18/20]  Loss: 0.8583  Accuracy: 73.76%
# Epoch [19/20]  Loss: 0.8362  Accuracy: 73.17%
# Epoch [20/20]  Loss: 0.8389  Accuracy: 73.62%
#
# Training Model: ('leaky_relu', 'kaiming', 'adam')
# Epoch [1/20]  Loss: 1.7701  Accuracy: 49.81%
# Epoch [2/20]  Loss: 1.4614  Accuracy: 55.97%
# Epoch [3/20]  Loss: 1.3239  Accuracy: 59.59%
# Epoch [4/20]  Loss: 1.2255  Accuracy: 62.39%
# Epoch [5/20]  Loss: 1.1669  Accuracy: 63.96%
# Epoch [6/20]  Loss: 1.1270  Accuracy: 65.72%
# Epoch [7/20]  Loss: 1.0830  Accuracy: 66.58%
# Epoch [8/20]  Loss: 1.0473  Accuracy: 68.62%
# Epoch [9/20]  Loss: 1.0105  Accuracy: 69.32%
# Epoch [10/20]  Loss: 0.9844  Accuracy: 69.62%
# Epoch [11/20]  Loss: 0.9511  Accuracy: 70.98%
# Epoch [12/20]  Loss: 0.9289  Accuracy: 70.84%
# Epoch [13/20]  Loss: 0.9094  Accuracy: 70.79%
# Epoch [14/20]  Loss: 0.8861  Accuracy: 73.15%
# Epoch [15/20]  Loss: 0.8690  Accuracy: 73.03%
# Epoch [16/20]  Loss: 0.8520  Accuracy: 73.49%
# Epoch [17/20]  Loss: 0.8342  Accuracy: 73.24%
# Epoch [18/20]  Loss: 0.8234  Accuracy: 73.85%
# Epoch [19/20]  Loss: 0.8076  Accuracy: 75.17%
# Epoch [20/20]  Loss: 0.7919  Accuracy: 75.38%
#
# Training Model: ('leaky_relu', 'kaiming', 'rmsprop')
# Epoch [1/20]  Loss: 1.9421  Accuracy: 47.31%
# Epoch [2/20]  Loss: 1.4981  Accuracy: 53.04%
# Epoch [3/20]  Loss: 1.3623  Accuracy: 56.68%
# Epoch [4/20]  Loss: 1.2640  Accuracy: 60.72%
# Epoch [5/20]  Loss: 1.2032  Accuracy: 59.04%
# Epoch [6/20]  Loss: 1.1559  Accuracy: 63.76%
# Epoch [7/20]  Loss: 1.1036  Accuracy: 65.79%
# Epoch [8/20]  Loss: 1.0628  Accuracy: 68.02%
# Epoch [9/20]  Loss: 1.0254  Accuracy: 66.08%
# Epoch [10/20]  Loss: 0.9980  Accuracy: 69.79%
# Epoch [11/20]  Loss: 0.9774  Accuracy: 69.22%
# Epoch [12/20]  Loss: 0.9575  Accuracy: 67.90%
# Epoch [13/20]  Loss: 0.9281  Accuracy: 70.59%
# Epoch [14/20]  Loss: 0.9147  Accuracy: 69.98%
# Epoch [15/20]  Loss: 0.8985  Accuracy: 70.54%
# Epoch [16/20]  Loss: 0.8845  Accuracy: 72.48%
# Epoch [17/20]  Loss: 0.8679  Accuracy: 70.41%
# Epoch [18/20]  Loss: 0.8530  Accuracy: 72.09%
# Epoch [19/20]  Loss: 0.8417  Accuracy: 72.37%
# Epoch [20/20]  Loss: 0.8318  Accuracy: 73.91%
#
# Training Model: ('leaky_relu', 'random', 'sgd')
# Epoch [1/20]  Loss: 1.6988  Accuracy: 50.84%
# Epoch [2/20]  Loss: 1.4212  Accuracy: 56.13%
# Epoch [3/20]  Loss: 1.2621  Accuracy: 61.89%
# Epoch [4/20]  Loss: 1.1417  Accuracy: 65.14%
# Epoch [5/20]  Loss: 1.0682  Accuracy: 66.77%
# Epoch [6/20]  Loss: 1.0178  Accuracy: 68.14%
# Epoch [7/20]  Loss: 0.9716  Accuracy: 68.37%
# Epoch [8/20]  Loss: 0.9422  Accuracy: 69.82%
# Epoch [9/20]  Loss: 0.9152  Accuracy: 71.10%
# Epoch [10/20]  Loss: 0.9021  Accuracy: 72.42%
# Epoch [11/20]  Loss: 0.8815  Accuracy: 72.20%
# Epoch [12/20]  Loss: 0.8630  Accuracy: 72.17%
# Epoch [13/20]  Loss: 0.8519  Accuracy: 73.38%
# Epoch [14/20]  Loss: 0.8405  Accuracy: 73.02%
# Epoch [15/20]  Loss: 0.8322  Accuracy: 73.85%
# Epoch [16/20]  Loss: 0.8189  Accuracy: 74.32%
# Epoch [17/20]  Loss: 0.8044  Accuracy: 74.32%
# Epoch [18/20]  Loss: 0.8045  Accuracy: 73.75%
# Epoch [19/20]  Loss: 0.7900  Accuracy: 74.11%
# Epoch [20/20]  Loss: 0.7824  Accuracy: 75.73%
#
# Training Model: ('leaky_relu', 'random', 'adam')
# Epoch [1/20]  Loss: 1.5538  Accuracy: 56.69%
# Epoch [2/20]  Loss: 1.2877  Accuracy: 60.07%
# Epoch [3/20]  Loss: 1.1750  Accuracy: 63.49%
# Epoch [4/20]  Loss: 1.1120  Accuracy: 65.34%
# Epoch [5/20]  Loss: 1.0549  Accuracy: 68.36%
# Epoch [6/20]  Loss: 1.0208  Accuracy: 68.52%
# Epoch [7/20]  Loss: 0.9863  Accuracy: 69.83%
# Epoch [8/20]  Loss: 0.9564  Accuracy: 70.45%
# Epoch [9/20]  Loss: 0.9316  Accuracy: 70.31%
# Epoch [10/20]  Loss: 0.9058  Accuracy: 71.74%
# Epoch [11/20]  Loss: 0.8935  Accuracy: 72.26%
# Epoch [12/20]  Loss: 0.8706  Accuracy: 73.34%
# Epoch [13/20]  Loss: 0.8498  Accuracy: 74.04%
# Epoch [14/20]  Loss: 0.8367  Accuracy: 74.09%
# Epoch [15/20]  Loss: 0.8292  Accuracy: 74.01%
# Epoch [16/20]  Loss: 0.8091  Accuracy: 74.78%
# Epoch [17/20]  Loss: 0.8027  Accuracy: 74.96%
# Epoch [18/20]  Loss: 0.7854  Accuracy: 75.07%
# Epoch [19/20]  Loss: 0.7707  Accuracy: 75.55%
# Epoch [20/20]  Loss: 0.7667  Accuracy: 75.92%
#
# Training Model: ('leaky_relu', 'random', 'rmsprop')
# Epoch [1/20]  Loss: 1.6539  Accuracy: 48.75%
# Epoch [2/20]  Loss: 1.3460  Accuracy: 57.13%
# Epoch [3/20]  Loss: 1.2156  Accuracy: 58.50%
# Epoch [4/20]  Loss: 1.1333  Accuracy: 60.54%
# Epoch [5/20]  Loss: 1.0826  Accuracy: 64.47%
# Epoch [6/20]  Loss: 1.0475  Accuracy: 67.56%
# Epoch [7/20]  Loss: 1.0011  Accuracy: 67.36%
# Epoch [8/20]  Loss: 0.9696  Accuracy: 69.80%
# Epoch [9/20]  Loss: 0.9430  Accuracy: 69.37%
# Epoch [10/20]  Loss: 0.9226  Accuracy: 66.87%
# Epoch [11/20]  Loss: 0.8986  Accuracy: 70.22%
# Epoch [12/20]  Loss: 0.8815  Accuracy: 72.35%
# Epoch [13/20]  Loss: 0.8662  Accuracy: 73.16%
# Epoch [14/20]  Loss: 0.8537  Accuracy: 72.90%
# Epoch [15/20]  Loss: 0.8334  Accuracy: 70.63%
# Epoch [16/20]  Loss: 0.8115  Accuracy: 71.48%
# Epoch [17/20]  Loss: 0.7975  Accuracy: 74.89%
# Epoch [18/20]  Loss: 0.7913  Accuracy: 73.38%
# Epoch [19/20]  Loss: 0.7807  Accuracy: 71.77%
# Epoch [20/20]  Loss: 0.7667  Accuracy: 74.99%

# %% [markdown]
# # 10. Computing best config model

# %%
results = {}
for key, metrics in history.items():
    results[key] = max(metrics["accuracy"])

best_config = max(results, key=results.get)
best_accuracy = results[best_config]

print("Best Configuration:")
print(f"Activation   : {best_config[0]}")
print(f"Init Method  : {best_config[1]}")
print(f"Optimizer    : {best_config[2]}")
print(f"Accuracy (%) : {best_accuracy:.2f}")
# Out:
# Best Configuration:
# Activation   : relu
# Init Method  : random
# Optimizer    : adam
# Accuracy (%) : 76.14

# %% [markdown]
# # 11. Saving models

# %%
os.makedirs("saved_models", exist_ok=True)
for key, model in models.items():
    act, init, opt = key
    filename = f"cnn_{act}_{init}_{opt}.pth"
    torch.save(model.state_dict(), os.path.join("saved_models", filename))

# %%
# !zip -r models.zip /content/saved_models/*
# Out:
#   adding: content/saved_models/cnn_leaky_relu_kaiming_adam.pth (deflated 7%)
#   adding: content/saved_models/cnn_leaky_relu_kaiming_rmsprop.pth (deflated 7%)
#   adding: content/saved_models/cnn_leaky_relu_kaiming_sgd.pth (deflated 7%)
#   adding: content/saved_models/cnn_leaky_relu_random_adam.pth (deflated 7%)
#   adding: content/saved_models/cnn_leaky_relu_random_rmsprop.pth (deflated 7%)
#   adding: content/saved_models/cnn_leaky_relu_random_sgd.pth (deflated 7%)
#   adding: content/saved_models/cnn_leaky_relu_xavier_adam.pth (deflated 7%)
#   adding: content/saved_models/cnn_leaky_relu_xavier_rmsprop.pth (deflated 7%)
#   adding: content/saved_models/cnn_leaky_relu_xavier_sgd.pth (deflated 7%)
#   adding: content/saved_models/cnn_relu_kaiming_adam.pth (deflated 7%)
#   adding: content/saved_models/cnn_relu_kaiming_rmsprop.pth (deflated 7%)
#   adding: content/saved_models/cnn_relu_kaiming_sgd.pth (deflated 7%)
#   adding: content/saved_models/cnn_relu_random_adam.pth (deflated 7%)
#   adding: content/saved_models/cnn_relu_random_rmsprop.pth (deflated 7%)
#   adding: content/saved_models/cnn_relu_random_sgd.pth (deflated 7%)
#   adding: content/saved_models/cnn_relu_xavier_adam.pth (deflated 7%)
#   adding: content/saved_models/cnn_relu_xavier_rmsprop.pth (deflated 7%)
#   adding: content/saved_models/cnn_relu_xavier_sgd.pth (deflated 7%)
#   adding: content/saved_models/cnn_tanh_kaiming_adam.pth (deflated 7%)
#   adding: content/saved_models/cnn_tanh_kaiming_rmsprop.pth (deflated 7%)
#   adding: content/saved_models/cnn_tanh_kaiming_sgd.pth (deflated 7%)
#   adding: content/saved_models/cnn_tanh_random_adam.pth (deflated 7%)
#   adding: content/saved_models/cnn_tanh_random_rmsprop.pth (deflated 7%)
#   adding: content/saved_models/cnn_tanh_random_sgd.pth (deflated 7%)
#   adding: content/saved_models/cnn_tanh_xavier_adam.pth (deflated 7%)
#   adding: content/saved_models/cnn_tanh_xavier_rmsprop.pth (deflated 7%)
#   adding: content/saved_models/cnn_tanh_xavier_sgd.pth (deflated 7%)

# %% [markdown]
# # 12. Accuracy plot

# %%
plt.figure(figsize=(14, 6))
for key, metrics in history.items():
    plt.plot(metrics["accuracy"], label=str(key))

plt.title("Accuracy Comparison Across All CNN Configurations")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.legend(fontsize=7, loc="best")
plt.grid(True)
plt.show()

# %% [markdown]
# # 13. Loss plot

# %%
plt.figure(figsize=(14, 6))

for key, metrics in history.items():
    plt.plot(metrics["loss"], label=str(key))

plt.title("Training Loss Comparison Across All CNN Configurations")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize=7, loc="best")
plt.grid(True)
plt.show()

# %% [markdown]
# # 14. Resnet training

# %%
import torchvision.models as tv_models

resnet18 = tv_models.resnet18(pretrained=True)
for param in resnet18.parameters():
    param.requires_grad = False

resnet18.fc = nn.Linear(resnet18.fc.in_features, 10)
resnet18 = resnet18.to(device)

resnet_optimizer = optim.Adam(resnet18.fc.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

resnet_losses, resnet_accuracies = train(
    resnet18,
    train_loader_cifar,
    test_loader_cifar,
    resnet_optimizer,
    criterion,
    epochs=20
)

resnet_key = ("resnet18", "pretrained", "adam")

models[resnet_key] = resnet18
history[resnet_key] = {
    "loss": resnet_losses,
    "accuracy": resnet_accuracies
}

results[resnet_key] = max(resnet_accuracies)
torch.save(resnet18.state_dict(), "saved_models/resnet18_cifar10.pth")

print("ResNet-18 training complete.")
print(f"Best Accuracy: {results[resnet_key]:.2f}%")
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 138MB/s]
# Epoch [1/20]  Loss: 1.8319  Accuracy: 39.40%
# Epoch [2/20]  Loss: 1.7319  Accuracy: 40.49%
# Epoch [3/20]  Loss: 1.7132  Accuracy: 40.27%
# Epoch [4/20]  Loss: 1.7138  Accuracy: 40.24%
# Epoch [5/20]  Loss: 1.7070  Accuracy: 40.11%
# Epoch [6/20]  Loss: 1.7034  Accuracy: 40.83%
# Epoch [7/20]  Loss: 1.7030  Accuracy: 41.09%
# Epoch [8/20]  Loss: 1.7047  Accuracy: 40.92%
# Epoch [9/20]  Loss: 1.7027  Accuracy: 41.64%
# Epoch [10/20]  Loss: 1.7077  Accuracy: 40.35%
# Epoch [11/20]  Loss: 1.7072  Accuracy: 40.68%
# Epoch [12/20]  Loss: 1.7002  Accuracy: 41.19%
# Epoch [13/20]  Loss: 1.7011  Accuracy: 40.09%
# Epoch [14/20]  Loss: 1.7014  Accuracy: 40.66%
# Epoch [15/20]  Loss: 1.7105  Accuracy: 40.45%
# Epoch [16/20]  Loss: 1.7080  Accuracy: 41.26%
# Epoch [17/20]  Loss: 1.7093  Accuracy: 41.85%
# Epoch [18/20]  Loss: 1.7013  Accuracy: 41.64%
# Epoch [19/20]  Loss: 1.6986  Accuracy: 40.83%
# Epoch [20/20]  Loss: 1.7028  Accuracy: 41.32%
# ResNet-18 training complete.
# Best Accuracy: 41.85%

# %% [markdown]
# # 15. Comparision (accuracy and loss)

# %%
best_cnn_history = history[best_config]
resnet_history = history[("resnet18", "pretrained", "adam")]

# %%
plt.figure(figsize=(8, 5))
plt.plot(best_cnn_history["accuracy"], label="Best CNN", linewidth=3)
plt.plot(resnet_history["accuracy"], label="ResNet-18", linewidth=3, linestyle="--")
plt.title("Accuracy Comparison: Best CNN vs ResNet-18")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.plot(best_cnn_history["loss"], label="Best CNN", linewidth=3)
plt.plot(resnet_history["loss"], label="ResNet-18", linewidth=3, linestyle="--")
plt.title("Loss Comparison: Best CNN vs ResNet-18")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()
